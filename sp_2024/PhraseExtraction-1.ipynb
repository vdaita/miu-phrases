# %%
import pandas as pd
from rapidfuzz import fuzz
from sentence_transformers import SentenceTransformer, util

df = pd.read_csv("company_website_second_round_with_additional_firms.csv", low_memory=True)
# Out:
# /tmp/ipykernel_112/416763055.py:5: DtypeWarning: Columns (300,304,325,328) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("company_website_second_round_with_additional_firms.csv", low_memory=True)

# %%
def split_df(df, num_dfs=15):
    total_columns = len(df.columns)
    columns_per_df = total_columns // num_dfs
    extra_columns = total_columns % num_dfs
    
    dfs = {}
    start_col = 0
    for i in range(num_dfs):
        end_col = start_col + columns_per_df + (1 if i < extra_columns else 0)
        dfs[f'df_{i}'] = df.iloc[:, start_col:end_col]
        start_col = end_col

    # Ensure no columns are missing
    original_columns = set(df.columns)
    split_columns = set(col for df_split in dfs.values() for col in df_split.columns)
    assert sum(len(dfs[f'df_{i}'].columns) for i in range(num_dfs)) == total_columns, "The total number of columns does not match."
    assert original_columns == split_columns, "Not all columns are accounted for in the split DataFrames."

    return dfs


dfs = split_df(df) # Dict keys: ['df_0', 'df_1', 'df_2', ... 'df_num_dfs']

# %%
def compute_hash(string):
    ans = 0
    for i in range(0, min(len(string), 8)):
        ans += ord(string[i]) * (7**i)
    return ans

# %%
table = {}

for index, row in enumerate(df.itertuples()):
    if index % 100 == 0:
        print(f"Finished processing {index} out of {len(df.index)} rows.")
    for value in row:
        if pd.isna(value) or type(value) == int:
            continue
        value_hash = compute_hash(value)
        
        if not(value_hash in table):
            table[value_hash] = []

        max_similarity = 0
        for existing_value in table[value_hash]:
            max_similarity = max(max_similarity, fuzz.ratio(existing_value, value))

        if max_similarity < 0.95:
            table[value_hash].append(value)
# Out:
# Finished processing 0 out of 5189 rows.
# Finished processing 100 out of 5189 rows.
# Finished processing 200 out of 5189 rows.
# Finished processing 300 out of 5189 rows.
# Finished processing 400 out of 5189 rows.
# Finished processing 500 out of 5189 rows.
# Finished processing 600 out of 5189 rows.
# Finished processing 700 out of 5189 rows.
# Finished processing 800 out of 5189 rows.
# Finished processing 900 out of 5189 rows.
# Finished processing 1000 out of 5189 rows.
# Finished processing 1100 out of 5189 rows.
# Finished processing 1200 out of 5189 rows.
# Finished processing 1300 out of 5189 rows.
# Finished processing 1400 out of 5189 rows.
# Finished processing 1500 out of 5189 rows.
# Finished processing 1600 out of 5189 rows.
# Finished processing 1700 out of 5189 rows.
# Finished processing 1800 out of 5189 rows.
# Finished processing 1900 out of 5189 rows.
# Finished processing 2000 out of 5189 rows.
# Finished processing 2100 out of 5189 rows.
# Finished processing 2200 out of 5189 rows.
# Finished processing 2300 out of 5189 rows.
# Finished processing 2400 out of 5189 rows.
# Finished processing 2500 out of 5189 rows.
# Finished processing 2600 out of 5189 rows.
# Finished processing 2700 out of 5189 rows.
# Finished processing 2800 out of 5189 rows.
# Finished processing 2900 out of 5189 rows.
# Finished processing 3000 out of 5189 rows.
# Finished processing 3100 out of 5189 rows.
# Finished processing 3200 out of 5189 rows.
# Finished processing 3300 out of 5189 rows.
# Finished processing 3400 out of 5189 rows.
# Finished processing 3500 out of 5189 rows.
# Finished processing 3600 out of 5189 rows.
# Finished processing 3700 out of 5189 rows.
# Finished processing 3800 out of 5189 rows.
# Finished processing 3900 out of 5189 rows.
# Finished processing 4000 out of 5189 rows.
# Finished processing 4100 out of 5189 rows.
# Finished processing 4200 out of 5189 rows.
# Finished processing 4300 out of 5189 rows.
# Finished processing 4400 out of 5189 rows.
# Finished processing 4500 out of 5189 rows.
# Finished processing 4600 out of 5189 rows.
# Finished processing 4700 out of 5189 rows.
# Finished processing 4800 out of 5189 rows.
# Finished processing 4900 out of 5189 rows.
# Finished processing 5000 out of 5189 rows.
# Finished processing 5100 out of 5189 rows.

# %%
unique_strings = []
for key in table:
    unique_strings.extend(table[key])
print(len(unique_strings))
# Out:
# 27691

# %%
sub_corpus = []
for i in range(0, len(unique_strings), 7000):
    max_idx = min(len(unique_strings), i + 7000)
    sub_corpus.append(unique_strings[i:max_idx])

# %%
import nltk
from nltk.corpus import stopwords

nltk.download("stopwords")

stopwords_list = stopwords.words('english')
embeddings_model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/vijayd2/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /opt/conda/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
def get_phrases(corpus, length=10, split=5):
    total_words = []
    for site in corpus:
        words = [word.lower() for word in site.split()]
        # words = [word for word in words if word not in stopwords_list]
        total_words.extend(words)

    phrases = []
    
    for i in range(0, len(total_words), split):
        right_idx = min(len(total_words), i + length)
        phrases.append(" ".join(total_words[i:right_idx]))
    
    return phrases

# %%
print(len(get_phrases(sub_corpus[0], length=20, split=15)))
# Out:
# 115874

# %%
del df

# %%
import heapq

def track_words(original_phrases, embedded_phrases, phrases, max_count=200):
    heap = []
    original_embedded = embeddings_model.encode(original_phrases)
    # embedded_phrases = embeddings_model.encode(phrases)
    print("Finished getting encodings")
    for pidx, embedded_phrase in enumerate(embedded_phrases):
        sim_sum = sum(util.cos_sim(original_embedded, embedded_phrase))
        heapq.heappush(heap, (sim_sum, phrases[pidx]))
        if len(heap) > max_count:
            heapq.heappop(heap)
    return heap

# %%
# phrases_for_extraction = {
#     "military": ["supporting our troops", "helping veterans", "first responders", "law enforcement"],
#     "anti-foreign": ["made in China", "low quality foreign imports", "sweap shop"],
#     "jobs": ["American workers", "job creation", "local jobs"],
#     "quality": ["last you a lifetime", "lifetime warranty", "american-made quality", "superior quality"],
#     "labor": ["labor condition and benefits", "sweat shops", "worker benefits", "partnerships with unions"],
#     "revival": ["make america great again", "MAGA", "american manufacturing", "reshoring manufacturing", "boosting america", "america first"]
# }

phrases_for_extraction = {
    "jobs_revised": ["job growth", "hiring from local communities", "boosting local jobs", "hire american"],
    "antiforeign_revised_2": ["non-imported", "low-quality foreign manufacturing", "low-quality outsourcing"],
    "quality_revised": ["american-made quality"],
    "labor_revised": ["labor condition and benefits", "sweat shops", "worker benefits", "partnerships with unions"],
    "national_pride_revised": ["pride", "proudly", "patriot", "patriotism"],
    "military_revised": ["veteran", "military", "first responder", "law enforcement", "supporting our troops"],
}

# %%
subcorpus_embeddings = []
subcorpus_phrases = []
for sc in sub_corpus:
    test_phrases = get_phrases(sc, length=20, split=15)
    extracted_phrases = embeddings_model.encode(test_phrases)
    subcorpus_phrases.append(test_phrases)
    subcorpus_embeddings.append(extracted_phrases)

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv(".env")

model = OpenAI(
    api_key=os.environ["OPENAI_API_KEY"]
)

def ask_llm_jobs(phrase):
    messages = [
        {"role": "system", "content": """Classify the following phrase as either: GENERAL, OFFER, or NEITHER. 
        The phrase should be classified as OFFER if it refers to a specific job offer the company is providing. 
        The phrase should be classified as GENERAL if it refers to a general attitude of supporting job growth in the United States.
        The phrase should be classified as NEITHER if it refers to neither or is miscellaneous."""},
        {"role": "user", "content": "Phrase: " + phrase},
    ]
        
    response = model.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=messages,
        max_tokens=100,
        temperature=0.1
    )

    return response.choices[0].message.content, "GENERAL"

def ask_llm_antiforeign(phrase):
    messages = [
        {"role": "system", "content": """Classify the following phrase as either: US, FOREIGN, NEITHER, or UNSURE. 
        The phrase should be classified as US if it refers solely to products being made in the United States. 
        The phrase should be classified as FOREIGN if it refers to goods that are being made abroad (both positively and negatively). 
        FOREIGN phrases can include references to products being manufactured in the United States, but must include a foreign component.
        The phrase should be classified as NEITHER if it doesn't refer to a location of manufacture or is miscellaneous.
        The phrase should be classified as UNSURE if you are unsure about which category it belongs in.
        
        Some examples of FOREIGN phrases are:
        1. "our small workshop in pennsylvania. made in china mass produced in a crowded chinese factory without any love or expertise."
        2. "of the 3-4 months typically required when importing from china. small batch customization is a service that is somewhat unique"
        3. "cheap imports, we take pride in creating quality handmade leather goods using full grain leather. our handmade buffalo leather goods"
        4. "corporations continue to rely on manufactures overseas because they can produce a lower cost product by using sweatshop labor (even"
        5. "39 years. in a time when ruthlessly cheap imports flood the market, we strive to make a product that is"

        Some examples of US phrases are:
        1. "quality denim and fabrics from our mill partners in usa, italy and japan a family company based in new york"
            Explanation: This is describing their partner locations in a neutrals tone, not anti foreign. Usually anti foreign is targeting developing countries, or just "foreign" imports in general. So there is a strong discriminatory element there.
        2. "are now made back in france. brand a - z | brand z - a | price low - high"
        3. "our global presence and robust delivery capabilities allow us to efficiently meet region-specific production needs, anywhere in the world. locations" This one is actually saying our global presence is a good thing, so it's the opposite idea.
        4. "we are working diligently to produce and ship quality bb simon products around the world, as efficiently as possible. we" Similar as 3. They are say we sell globally, which is a strength, so not bashing foreign products or bashing globalization.
        5. "internationally. we have a diversified range of innovative and quality products for consumer, plumbing, healthcare and oem/contract markets. you may"
        6. "research and development, manufacturing, and assembly operations in belgium, brazil, china, hungary, india, italy, mexico, the united kingdom, and the"
        
        """},
        
        {"role": "user", "content": "Phrase: " + phrase},
    ]
        
    response = model.chat.completions.create(
        model="gpt-4-0125-preview",
        messages=messages,
        max_tokens=100,
        temperature=0.1
    )
    return response.choices[0].message.content, "FOREIGN"

def ask_llm_labor_fairness(phrase):
    messages = [
        {"role": "system", "content": """Classify the following phrase as either: FAIRNESS, NOT. 
        The phrase should be classified as FAIRNESS if it describes ideas such as: "we pay a fair wage", "a decent wage to american workers", "they have good work conditions", etc.
        The phrase should be classified as NOT if it does not.
        """},
        
        {"role": "user", "content": "Phrase: " + phrase},
    ]
        
    response = model.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=messages,
        max_tokens=100,
        temperature=0.1
    )

    return response.choices[0].message.content, "FAIRNESS"

def ask_llm_military(phrase):
    messages = [
        {"role": "system", "content": """Classify the phrase as the following: MILITARY, NOT.
        The phrase should be classified as MILITARY if it explicitly states support for our military, law enforcement, and other public enforcement workers.
        The phrase should be classified as NOT if it does not.
        """},
        
        {"role": "user", "content": "Phrase: " + phrase},
    ]
        
    response = model.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=messages,
        max_tokens=100,
        temperature=0.1
    )

    return response.choices[0].message.content, "MILITARY"

def ask_llm_pride(phrase):
    messages = [
        {"role": "system", "content": """Classify the phrase as the following: PRIDE, NOT.
        The phrase should be classified as PRIDE if it explicitly states pride and patriotism for the United States.
        The phrase should be classified as NOT if it does not.
        """},
        
        {"role": "user", "content": "Phrase: " + phrase},
    ]
        
    response = model.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=messages,
        max_tokens=100,
        temperature=0.1
    )

    return response.choices[0].message.content, "PRIDE"


def ask_llm_quality(phrase):
    messages = [
        {"role": "system", "content": """Classify the phrase as the following: AMERICAN, NOT.
        The phrase should be classified as AMERICAN if it explicitly states the quality increase from goods being manufactured in the United States.
        The phrase should be classified as NOT if it does not.
        """},
        
        {"role": "user", "content": "Phrase: " + phrase},
    ]
        
    response = model.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        messages=messages,
        max_tokens=100,
        temperature=0.1
    )

    return response.choices[0].message.content, "AMERICAN"

# %%
import json

for phrase_key, ask_function in [("antiforeign_revised_2", ask_llm_antiforeign)]:
    all_extracted_phrases = []

    for scidx, sc in enumerate(sub_corpus):
        extracted_phrases = track_words(phrases_for_extraction[phrase_key], subcorpus_embeddings[scidx], subcorpus_phrases[scidx])
        for p in extracted_phrases:
            phrase = p[1]
            answer, keyword = ask_function(phrase)
            print("Phrase: ", phrase, " Answer: ", answer)
            if keyword in answer:
                all_extracted_phrases.append({"phrase": phrase, "certainty": "High"})
            elif "UNSURE" in answer:
                all_extracted_phrases.append({"phrase": phrase, "certainty": "Unsure"})
        
        save_file = open(f"{phrase_key}_phrases.json", "w")
        save_file.write(json.dumps(all_extracted_phrases, indent=4))
        save_file.close()
    
    print("NEW KEYWORD: ", phrase_key)
    print(all_extracted_phrases)
# Out:
# Finished getting encodings
# Phrase:  american store locator international distributors about us our story institutional press endorsements careers environmental stewardship faq contact us powders cleanser  Answer:  NEITHER
# Phrase:  and packaged by real people with really good intentions! we guarantee quality products and a positive customer service experience. if  Answer:  NEITHER
# Phrase:  our small workshop in pennsylvania. made in china mass produced in a crowded chinese factory without any love or expertise.  Answer:  FOREIGN
# Phrase:  decide how much you pay!highest quality standardsin the industry.high quality imagesand 3d view of all products.each product is fullycustomizable: metal,color,  Answer:  NEITHER
# Phrase:  quality denim and fabrics from our mill partners in usa, italy and japan a family company based in new york  Answer:  FOREIGN
# Phrase:  of the 3-4 months typically required when importing from china. small batch customization is a service that is somewhat unique  Answer:  FOREIGN
# Phrase:  the boxes. handmade in usa supporting the local economy and bringing quality manufacturing back to los angeles ethically made by  Answer:  US
# Phrase:  tool on the market 03. about our company about us we are a leading manufacturer and wholesale distributor of aftermarket  Answer:  NEITHER
# Phrase:  us it's our top priority to provide the greatest quality product and service to all of our customers. if you  Answer:  NEITHER
# Phrase:  of incoming packages and we will not be liable for any losses incurred. international shipping costs when placing an international  Answer:  NEITHER
# Phrase:  records of items purchased, their costs and product performance. monitor shipments and compliance to quality standards such as quality, delivery,  Answer:  NEITHER
# Phrase:  your customer we make plumbing parts in america got parts? ​are you a wholesaler? a repackager? a plumbing supply house?  Answer:  US
# Phrase:  made factory provides design and manufacturing services to individuals and brands looking to source and produce in the usa. clutch  Answer:  US
# Phrase:  foreign made caskets, in recent years the importing of foreign made caskets & coffins has increased dramatically, the wholesale costs  Answer:  FOREIGN
# Phrase:  factory in westville, new jersey to make sure you get what you need, when you need it. no foreign factory  Answer:  US
# Phrase:  how this company makes american products!lizlarge electrical contractorour go-to source for custom laddersbauer has been our go-to source for custom  Answer:  US
# Phrase:  civilianaire superior quality goods - american made men's women's civilianaire. superior quality goods, always american made shop stores stockists contact  Answer:  US
# Phrase:  the future as a small, family-owned business, quality is the first priority and will never be compromised. we use a  Answer:  NEITHER
# Phrase:  (pcr) rich products our partners produce, manufacture, or distribute, are either imported legally, or derived from 100% federally legal industrial  Answer:  NEITHER
# Phrase:  products online or direct to consumers. we are exclusively a lead generator for one of the largest global b2b suppliers  Answer:  NEITHER
# Phrase:  history of unequalled “k-9 craftsmanship!” “very happy to find a product of this quality while supporting jobs in our country“  Answer:  US
# Phrase:  be different. allowing bfg to create innovative gear made in the usa with quality you can trust. revolutionary load carriage  Answer:  US
# Phrase:  are made in other countries. get infoprivacy policy retailer login follow abilene   newsletter signupemail address: leave this field  Answer:  FOREIGN
# Phrase:  as good as the people who make it. as an organization we aim for the highest quality, not only in  Answer:  NEITHER
# Phrase:  ensure it meets the quality demands we set forth in our facility. the last stage is professional packaging where we  Answer:  NEITHER
# Phrase:  all clothing and 98 percent of all footwear is imported." -sourcingjournal.com newsletter subscribe to be the first to hear about  Answer:  FOREIGN
# Phrase:  strong engineering design capability, strategic alliances with quality manufacturers and a streamlined fully integrated supply chain.whether you are shooting a  Answer:  NEITHER
# Phrase:  joined forces and trained select manufactures to bring you the highest quality in design and function that we feel is  Answer:  NEITHER
# Phrase:  responsibility made in usa | free shipping over $175 x shop free swatch menu cart we are a seasonless line  Answer:  US
# Phrase:  well as your production requirements. "we are the factory." purchase american made - invest in "your" future.when you purchase american  Answer:  US
# Phrase:  we work closely with our factories to ensure the best quality build (including careful lay-up of carbon pieces, precision connection  Answer:  NEITHER
# Phrase:  cheap imports, we take pride in creating quality handmade leather goods using full grain leather. our handmade buffalo leather goods  Answer:  FOREIGN
# Phrase:  shipping and knowing you’re supporting jobs in the united states. belevation’s quality shows in how well the products last after  Answer:  US
# Phrase:  catalog request specifications counterfeits discontinued items find a dealer international distributors become a dealer knife care & maintenance tool &  Answer:  NEITHER
# Phrase:  our global presence and robust delivery capabilities allow us to efficiently meet region-specific production needs, anywhere in the world. locations  Answer:  US
# Phrase:  than lesser quality name brand mass production and equal quality furnishings "we are the factory," so don't be fooled by  Answer:  NEITHER
# Phrase:  us a unique manufacturer able to create entire handmade products of all styles in house with consistent quality. scottsdale art  Answer:  US
# Phrase:  in everyone from the suppliers and their employees to all the other businesses that prosper from putting previously unemployed people  Answer:  NEITHER
# Phrase:  “with imported parts” or like notices with our advertising. chippewa apologizes if this caused any confusion to its valued consumers.  Answer:  FOREIGN
# Phrase:  build all our boots and leather goods in our own factory and “usa made” rings true throughout all our products.  Answer:  US
# Phrase:  request specifications counterfeits discontinued items find a dealer international distributors become a dealer knife care & maintenance tool & knife  Answer:  NEITHER
# Phrase:  quality professional product line in contrast to mass-produced products that have little to do with quality, feel or design that  Answer:  NEITHER
# Phrase:  named "best import product" learn more the choice of oems for manufacturers everywhere. for stopping power anywhere. learn more the  Answer:  FOREIGN
# Phrase:  products are distributed into more than 90 countries dealer locator where to buy volné pozice customer service service and repairs  Answer:  NEITHER
# Phrase:  nothing leaves the cutco factory unless it lives up to our high quality standards. skilled workers perform quality checks throughout  Answer:  US
# Phrase:  engineering design capability, strategic alliances with quality manufacturers and a streamlined fully integrated supply chain. whether you are shooting prairie  Answer:  NEITHER
# Phrase:  to snuff, we simply won’t offer it. our inventory is selected with quality, organic certification, and fair trade certification in  Answer:  NEITHER
# Phrase:  every make of used import vehicles for sale, including bmw, honda, hyundai, infiniti, kia, lexus, mazda, mercedes, mini, nissan toyota,  Answer:  FOREIGN
# Phrase:  • janitorial supply • hospitality • facility maintenance • office / school supply learn more oem ami composites, our oem  Answer:  NEITHER
# Phrase:  cheap imports, we take pride in creating quality handmade leather goods using full grain leather. our handmade buffalo leather goods  Answer:  FOREIGN
# Phrase:  need it. no foreign factory can match our speed or quality. and our prices are good. that’s our promise. call  Answer:  FOREIGN
# Phrase:  help us to better serve our customers and allow us to provide quality products at the lowest possible prices. meanwhile  Answer:  NEITHER
# Phrase:  consumers must take heed and be ever vigilant when it comes to purchasing imported products. corporations continue to rely on  Answer:  FOREIGN
# Phrase:  quality manufacturing and design. all rights reserved.. powered by shopify newsletter sign up for our newsletter to stay in the  Answer:  NEITHER
# Phrase:  all rights reserved. support domestic manufacturing: made in the usa quality is victimless b r o k e n h  Answer:  US
# Phrase:  craft our products to order with only 100% american labor and source 99% of all of our materials from us  Answer:  US
# Phrase:  tools has been supplying 1000’s of manufacturing customers across north america with high quality usa made cutting tools at competitive  Answer:  US
# Phrase:  we manufacture and/or convert have been certified by an independent testing firm to be 100% made in america" shipping boxes,  Answer:  US
# Phrase:  and manufacturing services to individuals and brands looking to source and produce in the usa. free consult sign up. conceptualization  Answer:  US
# Phrase:  is custom built to your order in minnesota by our skilled technicians who still remember what "high fidelity" means. products  Answer:  US
# Phrase:  center merchandise find a dealer english (international) español (argentina / other south america) português (brazil) 简体中文 (china) dansk (denmark) français  Answer:  NEITHER
# Phrase:  are now made back in france. brand a - z | brand z - a | price low - high  Answer:  US
# Phrase:  find a store quality made in the u.s.a. americans have butchered and processed their own meat products for centuries. would  Answer:  US
# Phrase:  their background to bear to ensure you're receiving best-in-class products & that you're treated like family made in the usa  Answer:  US
# Phrase:  manufacturing allows for top notch customer service, short lead times on custom orders, and fast & inexpensive shipping. we are  Answer:  NEITHER
# Phrase:  will take the extra steps large distributors can't offer.through our warehousing distribution capabilities and educated sales force specializing in craft  Answer:  NEITHER
# Phrase:  us and the quality we stand for. learn more resources find printing tips, image resources, customer help and more! find  Answer:  NEITHER
# Phrase:  capabilities. our products are manufactured in facilities throughout north america and europe. learn more about industry leadership and expertise accuride  Answer:  FOREIGN
# Phrase:  art of quality manufacturing to the city of los angeles learn about our vision why us? why comunitymade? sure, there  Answer:  US
# Phrase:  corporations continue to rely on manufactures overseas because they can produce a lower cost product by using sweatshop labor (even  Answer:  FOREIGN
# Phrase:  producing high-quality clothing in the usa at an affordable price. by keeping our production in the usa we provide jobs  Answer:  US
# Phrase:  headquartered in china, and we work with a lot of chinese and other countries manufacters, we are in the centre  Answer:  FOREIGN
# Phrase:  making a difference for our dealers and the industries we serve? want to catch up with us at a trade  Answer:  NEITHER
# Phrase:  trade wars: what the average american needs to know the best products that are made in america some of our  Answer:  US
# Phrase:  is a world leader in manufacturing, marketing, and distributing of agricultural equipment. sold in more than 140 countries by over  Answer:  NEITHER
# Phrase:  on producing the best products in the us from domestic materials. we want to do as much as we can  Answer:  US
# Phrase:  products parts wholesale about us recipes immigrant's success story tool & die shop contact us c. palmer mfg. manufacturing high  Answer:  NEITHER
# Phrase:  healthcare manufacturing original equipment manufacturers retail state & local government telecommunications, media & entertainment small business solutions small business central  Answer:  NEITHER
# Phrase:  is a home grown, multi-generational business that manufactures all its cases in america. unparalleled customer service we care about you  Answer:  US
# Phrase:  compared to other vendors.”kevin m. from southeast region distributorlove this company!love how this company makes american products!lizlarge electrical contractorour go-to  Answer:  US
# Phrase:  all customers, employees, suppliers and competitors; resolve complaints in a timely manner; promote our products and services with integrity and  Answer:  NEITHER
# Phrase:  other businesses. we do our best to support american workers by offering a full line of made in the usa  Answer:  US
# Phrase:  future when you purchase american handmade products from saf, no matter how large or small, you employ americans and help  Answer:  US
# Phrase:  about us â–ş employment â–ş tour our factory â–ş become a dealer â–ş contact us proudly manufactured in the heart  Answer:  US
# Phrase:  high quality craftmanship and materials. at de martini globe canvas we are the factory. order your custom messenger shop everything  Answer:  NEITHER
# Phrase:  world of automotive manufacturing, staying ahead of competition and delivering high-quality vehicles to market in a timely manner is ...read  Answer:  NEITHER
# Phrase:  research and development, manufacturing, and assembly operations in belgium, brazil, china, hungary, india, italy, mexico, the united kingdom, and the  Answer:  FOREIGN
# Phrase:  one of the world’s largest and most respected manufacturers, serving people with quality since 1874. 5 generations of respect! unconditionally  Answer:  NEITHER
# Phrase:  stand behind our goods for their entire (second) lifetime. we’ll repair any original manufacturing defects for free, and we’re also  Answer:  NEITHER
# Phrase:  uncompromising commitment to quality, both through advanced design, state-of –the-art manufacturing and old world craftsmanship. czub manufactures a full line  Answer:  NEITHER
# Phrase:  low | best selling | new arrivals comoy's christmas 2017 pebble grain 186 sku: comoyxmas17186 country of originfrance finishsandblast shapebilliard  Answer:  FOREIGN
# Phrase:  respect all customers, employees, suppliers and competitors; resolve complaints in a timely manner; promote our products and services with integrity  Answer:  NEITHER
# Phrase:  u.s. waters of the pacific ocean.all treats and chews are carefully handcrafted in our own commercial kitchen. nothing is outsourced.  Answer:  US
# Phrase:  ”lean manufacturing.” customer satisfaction we take pride in crafting quality products that meet the high standards of our customers. thank  Answer:  NEITHER
# Phrase:  while maintaining my high quality standards. one way i've been able to do this is by selling only directly to  Answer:  NEITHER
# Phrase:  one-of-a-kind item we’ve sourced from artisans across the globe. as a woodworking supply store, we can equip crafters and diyers  Answer:  FOREIGN
# Phrase:  cheap polos, and other blank apparel from one of our locations or mill direct for sample or print purposes. simply  Answer:  NEITHER
# Phrase:  center merchandise find a dealer english (international) español (argentina / other south america) português (brazil) 简体中文 (china) dansk (denmark) français  Answer:  NEITHER
# Phrase:  about growing your business along with our own and enjoy transactions with like-minded individuals who recognize high-quality products offered at  Answer:  NEITHER
# Phrase:  with that. learn more shipping product from china to the us is a common occurance these days in our global  Answer:  FOREIGN
# Phrase:  united states. we have the best quality products, broadest product line, largest inventory, best service, highest fill rates and the  Answer:  NEITHER
# Phrase:  manufacturing original equipment manufacturers retail state & local government telecommunications, media & entertainment small business solutions small business central dell  Answer:  NEITHER
# Phrase:  or out source allowing us total control of our supreme quality as well as your production requirements. "we are the  Answer:  NEITHER
# Phrase:  a small manufacturing business here in the usa-veteran owned and operated in oceanside, ca. we are working diligently to provide  Answer:  US
# Phrase:  mexico resulting in lower quality products & jobs. we offer legendary service, quality and competitive pricing you can count on,  Answer:  FOREIGN
# Phrase:  we are working diligently to produce and ship quality bb simon products around the world, as efficiently as possible. we  Answer:  US
# Phrase:  usa - either in-house at our shop in capron, illinois, or locally under our direct supervision - using only top-quality  Answer:  US
# Phrase:  39 years. in a time when ruthlessly cheap imports flood the market, we strive to make a product that is  Answer:  FOREIGN
# Phrase:  which we operate is solely based upon quality and value. material used in our product is imported from various prominent  Answer:  FOREIGN
# Phrase:  internationally. we have a diversified range of innovative and quality products for consumer, plumbing, healthcare and oem/contract markets. you may  Answer:  US
# Phrase:  way of life: the command over materials, tools & processes. in an era of ruthlessly cheap imports, we take pride  Answer:  FOREIGN
# Phrase:  when you buy american made you insure your economic future our prices are always lower than lesser quality name brand  Answer:  US
# Phrase:  work hard to source high quality and responsibly produced materials in order to make premium products for our customers. opting  Answer:  NEITHER
# Phrase:  the highest-quality products, broadest product line, largest inventory, best customer service, highest fill rates and the greatest production capacity in  Answer:  NEITHER
# Phrase:  design. note: we do not import or outsource allowing us total control of our supreme quality as well as your  Answer:  US
# Phrase:  do not import or out source allowing us total control of our supreme quality as well as your production requirements.  Answer:  US
# Phrase:  new streamlined manufacturing process best is able to remain competitive in pricing in comparison to import kitchen tools.complete assortment of  Answer:  FOREIGN
# Phrase:  more found anywhere in the world in the 21st century. "we are the factory." purchase american made - invest in  Answer:  US
# Phrase:  finding a reputable supplier and managing the product development and importation required to source in china. if a customer approaches  Answer:  FOREIGN
# Phrase:  are always lower than lesser quality name brand mass production and equal quality furnishings "we are the factory," so don't  Answer:  NEITHER
# Phrase:  made short run production and contract manufacturing as rare as us based manufacturers themselves. it is our goal to manufacture  Answer:  US
# Phrase:  our operations. the quality of our products is our number one priority and while maintaining that quality during this dramatic  Answer:  NEITHER
# Phrase:  peace of mind. quality we focus on using the best materials around sourced from all over the globe. all in  Answer:  NEITHER
# Phrase:  our high quality standards are satisfied; there are no co-packers or private labeled products! we have been selling our usa  Answer:  US
# Phrase:  our production time and do quality control on every order leaving our warehouse. when you buy from us, you can  Answer:  NEITHER
# Phrase:  supplier information ergonomics requirements brazil mexico united states of america china india japan malaysia philippines singapore south korea thailand belgium  Answer:  NEITHER
# Phrase:  best prices. we are committed to this country, its future, and to supporting and promoting manufacturers determined to remain“made in  Answer:  US
# Phrase:  & return policy warranty information replacement parts catalog request specifications counterfeits discontinued items find a dealer international distributor become a  Answer:  NEITHER
# Phrase:  leading innovator of sanding and polishing equipment from italy. under the new ownership and operating as rupes usa, the new  Answer:  FOREIGN
# Phrase:  american work force and our ability to custom manufacture coinciding with construction deadlines. note: we do not import or out  Answer:  US
# Phrase:  more we believe in the quality and handcrafted process of local manufacturing. although it isn’t always easy, we make the  Answer:  US
# Phrase:  you insure your economic future our prices are always lower than lesser quality name brand mass production and equal quality  Answer:  NEITHER
# Phrase:  or out source allowing us total control of our supreme quality as well as your production requirements. scottsdale art factory  Answer:  NEITHER
# Phrase:  their parts from outside the us resulting in lower quality products. take it from us, we offer legendary service, quality,  Answer:  FOREIGN
# Phrase:  with products that are made in america. we source our inventory through companies that manufacture locally and find value in  Answer:  US
# Phrase:  goods that are sold worldwide. our products are proudly made from reliable materials and trusted sources. we understand the expectations  Answer:  NEITHER
# Phrase:  & operated factory in the usa, where their unwavering commitment to hand-crafted manufacturing processes deliver durable, state-of-the-art products at the  Answer:  US
# Phrase:  that we manufacture in our own closet factory ensuring top quality control. we source all wood materials from the pacific  Answer:  NEITHER
# Phrase:  owned / made in usa professional accessories skip to content submit close search free shipping on all orders over $55!  Answer:  US
# Phrase:  our products will always be different. allowing bfg to create innovative gear made in the usa with quality you can  Answer:  US
# Phrase:  north america with high quality usa made cutting tools at competitive prices, combined with great customer service.don’t see what you  Answer:  US
# Phrase:  the are functional, practical and durable. in a world obsessed with hyper production and ruthlessly cheap imports, we pride ourselves  Answer:  FOREIGN
# Phrase:  of life: the command over materials, tools & processes. in an era of ruthlessly cheap imports, we take pride in  Answer:  FOREIGN
# Phrase:  us | our partnersmro & distribution divisioncommitment to qualitycontact us | area sales managersoem representativesc&h organizationquote requestsample requestquoteassembliesair cooled assembliesliquid  Answer:  NEITHER
# Phrase:  making sustainable products that are shipped here from overseas. we encourage customers to buy from local brick and mortar stores  Answer:  FOREIGN
# Phrase:  | diy projects | new products | home choose country africa argentina austria australia belgium brazil canada chile china colombia  Answer:  NEITHER
# Phrase:  commercial kitchen. nothing is outsourced. this gives us unparalleled control over quality, starting at the farms and fisheries we buy  Answer:  US
# Phrase:  is sourced from the most trusted and renowned producers in italy, spain, switzerland, and japan, as well as luxurious domaine  Answer:  FOREIGN
# Phrase:  direct to professional technicians across the country. our brand is recognized as a leading manufacturer of quality products sold via  Answer:  NEITHER
# Phrase:  been serving original equipment manufacturers (oems) throughout all industries as a complete contract electronic manufacturer (cem) specializing in smt and  Answer:  NEITHER
# Phrase:  customs certified mechanics on staff low labor rates discounted supplies & parts parts & accessories all makes & models american  Answer:  NEITHER
# Phrase:  in the u.s.a., but also contained parts manufactured outside the united states. we now include “with imported parts” or like  Answer:  FOREIGN
# Phrase:  command over materials, tools & processes. in an era of ruthlessly cheap imports, we take pride in creating quality handmade  Answer:  FOREIGN
# Phrase:  information replacement parts catalog request specifications counterfeits discontinued items find a dealer international distributor become a dealer dealer - pay  Answer:  NEITHER
# Phrase:  production requirements. "we are the factory." purchase american made - invest in "your" future.when you purchase american made products no  Answer:  US
# Phrase:  products, and all of our products made in the u.s.a. this keeps manufacturing jobs here and shortens shipping distances, thus  Answer:  US
# Phrase:  expertly constructed in our own immaculate factories with a combination of old world craftsmanship and state-of-the-art engineering. our products are  Answer:  NEITHER
# Phrase:  other countries as needed only after passing channellock, inc.'s rigorous quality standards. products pliersscrewdriversspecialty toolswrenchesproduct catalog trades trades 101trades commitmenttrade  Answer:  NEITHER
# Phrase:  brands looking to source and produce in the usa. we are the factory you can talk to.our latest posts scrunchie  Answer:  US
# Phrase:  makers manufacture high quality, inimitable pieces that are made to order and can’t be found anywhere else. read more comfort  Answer:  NEITHER
# Phrase:  shipping and knowing you’re supporting jobs in the united states. belevation’s quality shows in how well the products last after  Answer:  US
# Phrase:  our online product is imported from various prominent sources around the world. we only use high quality precious bridal metals  Answer:  FOREIGN
# Phrase:  and our ability to custom manufacture coinciding with construction deadlines. note: we do not import or out source allowing us  Answer:  NEITHER
# Phrase:  manufacturing original equipment manufacturers retail state & local government telecommunications, media & entertainment small business solutions small business central dell  Answer:  NEITHER
# Phrase:  free printed in the usa owned and operated in the usa by american workers and owners. reduce and reuse reduce  Answer:  US
# Phrase:  the same standards of quality that have been used since its inception in the market. location nos encontramos ubicados en  Answer:  NEITHER
# Phrase:  in confidence from one of the largest novelty manufacturers in the country at the lowest wholesale prices. we carry hundreds  Answer:  NEITHER
# Phrase:  us shipping & return policy warranty information replacement parts catalog request specifications counterfeits discontinued items find a dealer international distributor  Answer:  NEITHER
# Phrase:  master crafted in america since 1913. our prices are usually lower than lesser quality name brand mass production imports, this  Answer:  FOREIGN
# Phrase:  and boxed from asia. even those us brands that people are familiar with now outsource their production, often from the  Answer:  FOREIGN
# Phrase:  the factory, the client and the other vendors: a dramedy in many parts tech pack: what it is and what  Answer:  NEITHER
# Phrase:  usa, where their unwavering commitment to hand-crafted manufacturing processes deliver durable, state-of-the-art products at the fairest prices. our story general  Answer:  US
# Phrase:  lesser quality, name brand, mass production manufacturers, as well as most other so called custom shops. we always guarantee the  Answer:  NEITHER
# Phrase:  parts from outside the us resulting in lower quality products. take it from us, we offer legendary service, quality, &  Answer:  FOREIGN
# Phrase:  of our products are produced in the united states. this keeps manufacturing jobs here and shortens shipping distances lowering our  Answer:  US
# Phrase:  us only) craft & quality guaranteed safe & secure checkout free & fast shipping(continental us only) copyright © 2021 carruth  Answer:  US
# Phrase:  we stick to here is making our goods in the usa. read more contact us for questions and inquiries please  Answer:  US
# Phrase:  made shoe companies we believe in supporting the local economy and bringing back the lost art of quality manufacturing to  Answer:  US
# Phrase:  ask their chinese (or taiwanese) factory partner for the order, and that factory will likely also reject anything in low  Answer:  FOREIGN
# Phrase:  do not import or out source allowing us total control of our supreme quality as well as your production requirements.  Answer:  US
# Phrase:  recognize high-quality products offered at affordable prices.learn what it takes to get started with us and become a distributor or  Answer:  NEITHER
# Phrase:  a top supplier of workholding and striking tools that deliver the epitome of quality, innovation and durability. started in chicago  Answer:  US
# Phrase:  prices and exceptional service. our products are carefully curated by our experienced sourcing and quality control team. moreover, all products  Answer:  NEITHER
# Phrase:  business sell in your store use in company equipment which is right for you? international inquiries become a dealer sell  Answer:  NEITHER
# Phrase:  you are in good hands with a company that is focused on creating high quality products. view all products de  Answer:  NEITHER
# Phrase:  and our ability to custom manufacture coinciding with construction deadlines. note: we do not import or out source allowing us  Answer:  US
# Phrase:  brand mass production imports, this is because "we are the factory," so don't be fooled by our upscale appearance. "  Answer:  FOREIGN
# Phrase:  manufacturing in the usa. we are grateful to the many brands, distributors, retailers and other companies that trust us to  Answer:  US
# Phrase:  see more we believe in the quality and handcrafted process of local manufacturing. although it isn’t always easy, we make  Answer:  US
# Phrase:  with american labor and materials handcrafted quality for years of use few week turnaround with expedited options solid sustainably managed  Answer:  US
# Phrase:  partnership with an international firm that specializes in the business, marketing, development, and manufacturing of superior audio products to complement  Answer:  NEITHER
# Phrase:  we ship out is up to the high-quality standards that we have set and maintained for ourselves over the years.  Answer:  NEITHER
# Phrase:  way of life: the command over materials, tools & processes. in an era of ruthlessly cheap imports, we take pride  Answer:  FOREIGN
# Phrase:  upscale appearance, our prices are usually less then lesser quality production imports, because "we are the factory." over nine decades  Answer:  FOREIGN
# Phrase:  excellent qualitywe add value for our customers throughout the supply chain with an unwavering commitment to quality products, service and  Answer:  NEITHER
# Phrase:  command over materials, tools & processes. in an era of ruthlessly cheap imports, we take pride in handcrafting each item  Answer:  FOREIGN
# Phrase:  domestically sourced materials whenever possible" artifact | handmade aprons, bags, & accessories | made in usa small batch handmade in  Answer:  US
# Phrase:  able. note: we do not import or out source allowing us total control of our supreme quality as well as  Answer:  US
# Phrase:  american made you insure your economic future our prices are always lower than lesser quality name brand mass production and  Answer:  US
# Phrase:  order, we include a certificate of origin, proving our transparency and dedication to quality. we bypass imported, subpar alternatives, often  Answer:  FOREIGN
# Finished getting encodings
# Phrase:  we have pretty high standards and quality control, from the initial cnc machining to the final fit and finish which  Answer:  NEITHER
# Phrase:  for authenticity and quality, elegance, and innovation. they still do.learn moreour factory in rochester, new york — widely known as  Answer:  US
# Phrase:  the imports but this is the best shirt of its kind in the usa. tough and really good looking. a  Answer:  US
# Phrase:  tooling with competitive prices and fast delivery. view products kaiser tool company manufacturing thinbit® in the usa since 1964. view  Answer:  US
# Phrase:  a dealer a&d representatives careers our brands haworth bluescape buzzispace cappellini cassina hushoffice janus et cie poltrona frau tuohy partner  Answer:  NEITHER
# Phrase:  lower prices. totally secure credit card sales. made in the u.s.a. thread mills are our specialty. free ground shipping on  Answer:  US
# Phrase:  the usa by expert chime manufacturers. this means top-quality materials and warranties on the chimes. join our newsletter receive our  Answer:  US
# Phrase:  from branded merchandise and fulfillment to print solutions and all the related services that support your activities. whether it’s an  Answer:  NEITHER
# Phrase:  for providing the highest quality shop service equipment for the automotive, truck and service vehicle industries. world's greatest to view  Answer:  NEITHER
# Phrase:  contact us dealers only privacy policy disclaimer site map © 2015 dutchmen manufacturing. all rights reserved. content on this page  Answer:  NEITHER
# Phrase:  in the industry free shipping to 48 states technical support easy assembly & care local dealers extensive warranty coverage company  Answer:  NEITHER
# Phrase:  r t o o l c o m p a n y • quality products • fast delivery • •  Answer:  NEITHER
# Phrase:  be a zero waste company and are committed to providing exceptional handmade quality and customer service. it's time for businesses  Answer:  NEITHER
# Phrase:  him shop now — exclusively — ours shop now handcrafted in america if the words "made in usa" are important  Answer:  US
# Phrase:  aim to provide the lowest price possible on high-quality equipment — not second-rate machinery.learn more about gnegne brands and partnerswe  Answer:  NEITHER
# Phrase:  falls directly on us, we back each dealer with handyū industries 100% satisfaction guarantee. click here to enter web 2  Answer:  NEITHER
# Phrase:  are you visiting us as a private consumer or trade customer?privatetradeproductsallchairsstoolsbenches & daybedstablesoutdoor furnitureaccessories & partsaboutnewsabout emecosustainabilitymade in usadesignersemeco housecontactresourcesdownloads  Answer:  US
# Phrase:  quality-control reviews before being placed into the shipping carton for delivery to one of our dealers from around the world.  Answer:  NEITHER
# Phrase:  offer our own manufactured products, but also products from many other top manufactures as well. like our customers we are  Answer:  NEITHER
# Phrase:  & recognition programs• custom & special event merchandise• supply chain management• global product sourcing multichannel fulfillment the right order to  Answer:  NEITHER
# Phrase:  visa eco luxury throws and accessories, knit in the usa – in2green free shipping in the usa! cart 0 search  Answer:  US
# Phrase:  and manufacturing innovation to provide essential products of outstanding performance, quality and value worldwide. © 2021 the gerson company. all  Answer:  NEITHER
# Phrase:  modules in our american and canadian facilities. the supply chains are short, and our modules are never held up in  Answer:  US
# Phrase:  china dänemark deutschland frankreich indien niederlande schweden großbritannien usa komplette liste öffnen kundenservice produkt- und kundensupport versand rücksendung bestellstatus formular  Answer:  FOREIGN
# Phrase:  csathey have the responsibility of certifying processes and products entering into their respective country markets.atexdirectives for standardization that cover equipment  Answer:  NEITHER
# Phrase:  all to cart loading... chat with us, powered by livechat firearms, firearms parts & accessories manufacturer. import and export dsa  Answer:  FOREIGN
# Phrase:  suppliers through a comprehensive marketing and training partnership. this partnership helps members provide high quality, value added products and services  Answer:  NEITHER
# Phrase:  and accessories from all over the world at highly competitive prices. today, the company is the largest unit producer of  Answer:  NEITHER
# Phrase:  been set up to give you the lowdown on everything ibis. our uk and french distributors also maintain their own  Answer:  FOREIGN
# Phrase:  main content find a dealer parts & service finance online parts build my kubota kubota country merchandise go to home  Answer:  NEITHER
# Phrase:  delivers solutions with every product line we carry. if you want to grow your business and proudly offer quality brands  Answer:  NEITHER
# Phrase:  quality truckxchange - e-commerce solutions for the global commercial vehicle industry used truck locator - locate your next used truck  Answer:  NEITHER
# Phrase:  ‣no personal identifying information (e.g., customer phone number or email) ‣no competitor references (e.g., another brand or dealership) ‣dangerous behavior  Answer:  NEITHER
# Phrase:  committed to make all of our clothing here in the usa. made to last tailor shop to repair, improve and  Answer:  US
# Phrase:  crafters (some other product categories imported so look for "made in usa" in product descriptions). paterson hand tools, craft blades,  Answer:  FOREIGN
# Phrase:  committed to making everything in the usa while we watch more and more companies move overseas to make their clothes  Answer:  US
# Phrase:  themselves on their cases' artistic finishes, and a pristine fit is paramount.” worldwide shipping no matter where you are, grove  Answer:  NEITHER
# Phrase:  new partsinternational shipping.if you need an order shipped outside the usa, email us with the parts you need and we  Answer:  NEITHER
# Phrase:  tell us your requirements and we will fulfill them with competitive prices, quality products and prompt delivery. who we are  Answer:  NEITHER
# Phrase:  order to serve you better, handyū industries provides dealers throughout the world. these dealers have met handy's strict criteria and  Answer:  NEITHER
# Phrase:  in. we pride ourselves on manufacturing the majority of our products in our own facility, and partner primarily with other  Answer:  US
# Phrase:  clients that us based manufacturing can be done and that it can be done successfully - that's why we're here.  Answer:  US
# Phrase:  technology as well as time tested manufacturing methods to produce high quality, low cost products.from design though manufacturing, each step  Answer:  NEITHER
# Phrase:  products are made in the usa and used in a wide variety of market application which demand high-quality, high-strength precision  Answer:  US
# Phrase:  reliable, easily serviced and surprisingly affordable—this is everything you need to get from a to b in one quality, made-in-america,  Answer:  US
# Phrase:  that we can continue to provide the quality you have come to expect from florian tools. all items on backorder  Answer:  NEITHER
# Phrase:  20% off… shop now free shipping on all orders over $50 within the contiguous usa hand crafted in the usa  Answer:  US
# Phrase:  in legal terms) enjoys a solid reputation throughout the world. “swiss made" embodies a concept of quality that has been  Answer:  FOREIGN
# Phrase:  is important and that america's veterans are our greatest resource. that's why we only source american suppliers, make every product  Answer:  US
# Phrase:  free.we’ve been innovators from the very beginning. founded in 1889, we create quality products that last a lifetime. our replacement  Answer:  NEITHER
# Phrase:  sourced in the us, to the market. join us on kickstarter! get exclusive news and deals get deals and product  Answer:  US
# Phrase:  small batch and large scale manufacturing services for independent designers and established brands alike utilizing manufacturing facilities in fall river,  Answer:  FOREIGN
# Phrase:  shipping.*) leave a comment made in usa: quality. pride. innovation. posted on june 23, 2015 by jason yoakam every handy®  Answer:  US
# Phrase:  world at highly competitive prices. today, … learn moreour company was founded on the basic principle that delivering a quality  Answer:  NEITHER
# Phrase:  warranty international shipping & returns product registration dealer locator catalogs media our brands team blog your cart close cart site  Answer:  NEITHER
# Phrase:  gladly supply warranty and insurance certificates on all our products. your satisfaction is guaranteed. member aoca worldwide export we accept  Answer:  NEITHER
# Phrase:  able to be totally self sufficient and never again rely on a foreign manufacturer. thank you for your interest in  Answer:  FOREIGN
# Phrase:  supporting made in usa companies or fair trade. please go out and support your local shops and restaurants. ask us  Answer:  US
# Phrase:  manufacturers that make the product in america. not a single component that we use is imported. that's what we believe  Answer:  US
# Phrase:  in the automotive aftermarket. differing from competition by ensuring that quality is a focus in everything lokar, whether it is  Answer:  NEITHER
# Phrase:  control laws and regulations of other countries. you are responsible for obtaining any license to export, re-export, or import as  Answer:  NEITHER
# Phrase:  quality basics for over 15 years. we pride ourselves in keeping our apparel manufacturing in the u.s. operating our manufacturing  Answer:  US
# Phrase:  principle that delivering a quality product at a reasonable price and in a timely manner is not simply the best  Answer:  NEITHER
# Phrase:  service. all of our manufactured products are held to the highest quality standards. this accomplishment emphasizes our ongoing commitment to  Answer:  NEITHER
# Phrase:  the usa. competence full service supplier predevelopment / development manufacturing technologies cooperations fischer group of companies fixing systems fischer consulting  Answer:  NEITHER
# Phrase:  the innovative, clean, and streamlined d... 10 5 read full story share kinze manufacturing, inc.5 days 16 hours agoour hearts  Answer:  NEITHER
# Phrase:  to content home about our products imported products order form links directions news home american made kitchen supplies kwik-kut manufacturing  Answer:  FOREIGN
# Phrase:  american suppliers, make every product by hand, and our entire team is made up of service disabled combat veterans. every  Answer:  US
# Phrase:  we the largest manufacturer of premium-quality wire connectors, we build tools, conduit benders, fish tapes and countless other products made  Answer:  US
# Phrase:  or manufacturing. they do not abandon their clients and rather they want the customer to come away satisfied. this goes  Answer:  NEITHER
# Phrase:  the usa from the florian family to yours discover the top 3 reasons customers have returned to our tools loyally  Answer:  US
# Phrase:  the usa by sourcing only the highest quality, organic ingredients. experience how effective and tasty results are possible without harming  Answer:  US
# Phrase:  we are 100% dedicated to providing the highest quality products at a reasonable price and the highest level of customer  Answer:  NEITHER
# Phrase:  of values – quality, innovation and engineering excellence. find quality products, top notch service and financing to meet the needs  Answer:  NEITHER
# Phrase:  dealers that stock an inventory of dustless tools' products by enabling the check box.due to challenges with shipping between various  Answer:  NEITHER
# Phrase:  and innovative products. see more > reps & distributors see all of our domestic and international manufacture representatives here. contact  Answer:  NEITHER
# Phrase:  shop made in usa join the i+w mailing list get first dibs on limited edition releases + stay up to  Answer:  US
# Phrase:  tools' products by enabling the check box.due to challenges with shipping between various countries, international inquiries must be handled on  Answer:  NEITHER
# Phrase:  united states. we're offering high performance, fiberglass & wooden racquets manufactured at our factory in brazil & u.s.a. now shipping  Answer:  FOREIGN
# Phrase:  responsibility of certifying processes and products entering into their respective country markets.atexdirectives for standardization that cover equipment and protective systems  Answer:  NEITHER
# Phrase:  to our valued customers outside of the u.s.a. thank you for your interest in dsa, inc. products. there are some  Answer:  NEITHER
# Phrase:  manufacturing we specialize in the foodservice and restaurant industries. custom engineering and manufacturing for both inside and outside the box  Answer:  NEITHER
# Phrase:  made in the u.s.a promises fair labor and product quality standards. we make eco-friendly clothing they can look good in  Answer:  US
# Phrase:  as time tested manufacturing methods to produce high quality, low cost products. from design though manufacturing, each step is evaluated  Answer:  NEITHER
# Phrase:  us auto replenishment store locator usa usa usa australia austria beneluxe dutch english french brazil canada english french chile china  Answer:  NEITHER
# Phrase:  original factory inventory or are new parts made from oem production suppliers. the nos parts were stored in various warehouses  Answer:  NEITHER
# Phrase:  distributors that will save time and money. because rebuilding your distributor is an advanced project that requires specialized tools, and  Answer:  NEITHER
# Phrase:  front office, and we are all dedicated to accuracy, efficiency and quality packaging. we don't use 3pl companies to send  Answer:  NEITHER
# Phrase:  states © harman international industries, inc. jbl europe france united kingdom germany netherlands north america united states © harman international  Answer:  NEITHER
# Phrase:  custom labels. custom manufacturing. promotional products. rush services. no minimums. sewing and heat seal services in san diego, ca. >>  Answer:  US
# Phrase:  and our modules are never held up in port or customs. and we meet requirements for the buy american and  Answer:  US
# Phrase:  a family-owned and operated company, we retain a level of customer service and product quality that remains unmatched by our  Answer:  NEITHER
# Phrase:  "knockoffs" are generally imports made from fabric from china) support the american worker. try to buy goods made in u.s.a.  Answer:  FOREIGN
# Phrase:  products and great personal offers free international delivery free worldwide delivery with orders over £350 help contact us corporate responsibility  Answer:  NEITHER
# Phrase:  ever growing outlets in europe and asia. thank you for choosing johnson woolen mills where we integrate old world values  Answer:  NEITHER
# Phrase:  ‘made in america’ interview family run. american made…in the age of outsourcing to the lowest bidder, excel dryer remains committed  Answer:  US
# Phrase:  highest-quality products right here at home. all products are made in usa certified, and excel strives to locally source all  Answer:  US
# Phrase:  arrive with the goods in excellent condition. everyone in the supplier and consumer chain from your sales representatives and wholesalers  Answer:  NEITHER
# Phrase:  its quality you can trust because for 20+ years we've prided ourselves on being made in america and handcrafted in  Answer:  US
# Phrase:  using fair trade standards which are intended to support and honor the intense human effort that is required with every  Answer:  NEITHER
# Phrase:  of our competitors are claiming "u.s.a made" when in fact they are using fabric from china or some other offshore  Answer:  FOREIGN
# Phrase:  business with paccar -edi - electronic data interchange preferred suppliers - the road to total quality truckxchange - e-commerce solutions  Answer:  NEITHER
# Phrase:  of the way. expert manufacturing for the integrity of our products, we keep our manufacturing processes local. our woodshop is  Answer:  US
# Phrase:  owner supplier information press releases philosophy locations products competence full service supplier predevelopment / development manufacturing technologies cooperations quality company  Answer:  NEITHER
# Phrase:  improving out products. most importantly, by employing a local workforce instead of offshore manufacturing, we keep a very tight handle  Answer:  US
# Phrase:  are imported.) albertville jack of all shades - home home custom hardback we are a u.s. manufacturer. we make any  Answer:  US
# Phrase:  shipping what our customers say one of the best small businesses in the us for online knife and tool buying,  Answer:  NEITHER
# ...
# Phrase:  in our own los angeles, ca factory to ensure our standards are fully executed.vertically-integrated, local, and traceable production maximizes quality,  Answer:  US
# Phrase:  here inthe usa. this allows us to offerexceptional quality, value and timing. see our process view the gallery explore a  Answer:  US
# Phrase:  customers consistently inquire about products that are 100% usa made as they are fed up with import jacks with failure  Answer:  FOREIGN
# Phrase:  a step further by sourcing and buying all our materials in the united states and italy, so you have the  Answer:  US
# Phrase:  industry through unmatched customer service and manufacturing the best products in the business. all of our products are made in  Answer:  US
# Phrase:  kentucky. to compete successfully against products made in asia, we must focus on producing the highest quality products at the  Answer:  FOREIGN
# Phrase:  imported by import brands alliance, st. louis, mo home | terms & conditions | privacy policy 1-800-my-chalice | stella artois  Answer:  FOREIGN
# Phrase:  write this article. a quality product is so much more than the sum of the parts yet at the same  Answer:  NEITHER
# Phrase:  to the highest quality standards in the industry. you can count on them to be exactly what you need. our  Answer:  NEITHER
# Phrase:  locally source all our raw materials with sustainable manufacturing processes in mind. our operations provide countless manufacturing jobs bringing skilled,  Answer:  NEITHER
# Phrase:  parts yet at the same time a quality product needs to be made from quality parts, so sometimes we have  Answer:  NEITHER
# Phrase:  bring your concepts to life, and rely on our manufacturing processes for exacting quality, 99.5% on-time delivery, and three-week lead  Answer:  NEITHER
# Phrase:  jobs by producing high-quality clothing in the usa at an affordable price. by keeping our production in the usa we  Answer:  US
# Phrase:  manufactured in our own modern factory in gloversville, new york, usa! we do not import uppers; we do not import  Answer:  US
# Phrase:  where made in the usa quality products. let's commit to buying products made in the usa. i am driving a  Answer:  US
# Phrase:  we don't have to sacrifice quality because of production demands. by selling directly to the consumer, we can sell the  Answer:  NEITHER
# Phrase:  we use is the highest quality available and only made in the u.s.a. don't accept cheap, overseas substitutes! http://tempflow.com/wp-content/uploads/2017/09/dcf421da-6a23-7636-379d-82d5f2e37234-1.mp3 better  Answer:  FOREIGN
# Phrase:  products in the world. we have stood the test of time in the industry through unmatched customer service and manufacturing  Answer:  NEITHER
# Phrase:  to source locally, create local jobs, and most importantly, provide industry-leading quality control and customer care. read more what people  Answer:  NEITHER
# Phrase:  + support wall street journal seahorse magazine the onion sailing world stowe telecom, llc - a business process outsource vendor  Answer:  NEITHER
# Phrase:  highest quality materials all our products are designed in america, and we only source raw materials from the u.s. we  Answer:  US
# Phrase:  made in asia, we must focus on producing the highest quality products at the lowest possible cost while providing the  Answer:  FOREIGN
# Phrase:  italy, so you have the best possible product. design and quality are never compromised. labor is always to us standards.read  Answer:  US
# Phrase:  in computer-aided design & computer-aided manufacturing, and we produce components for oem’s in many industries. our services / capabilities shinola  Answer:  NEITHER
# Phrase:  science and part art, requiring specialized know-how and total supply chain responsibility, quality and transparency from beginning to end.source-verifiedduckworth is  Answer:  NEITHER
# Phrase:  usa! we do not import uppers; we do not import labor; we do not import shoes! you can order in  Answer:  US
# Phrase:  strict emphasis on quality and value. each of our products are purposely designed to be the best available in their  Answer:  NEITHER
# Phrase:  by following everything this country stood for from loyalty to quality. we decided to source our leather from two of  Answer:  US
# Phrase:  customers with high quality products and service. if you are looking for an unreasonable low cost, low quality, and shady  Answer:  NEITHER
# Phrase:  are a small business. we manufacture our products in kentucky. to compete successfully against products made in asia, we must  Answer:  US
# Phrase:  policy to continuously improve and maintain our ability to produce quality parts to satisfy our customers and make a fair  Answer:  NEITHER
# Phrase:  difference assembled in the usa we take pride in the high quality of our products. that's why every item is  Answer:  US
# Phrase:  there are several factors that business owners must consider. with many options available in the market, finding the perfect supplier  Answer:  NEITHER
# Phrase:  countless manufacturing jobs bringing skilled, quality craftsmanship back to america. we take pride in delivering the highest quaility products in  Answer:  US
# Phrase:  specific systems and applications. potential oem customers consistently inquire about products that are 100% usa made as they are fed  Answer:  US
# Phrase:  industry is a mess. currently there is minimal government oversight and a huge variety of ineffective extraction and delivery methods.  Answer:  NEITHER
# Phrase:  surpass the quality control checks of import jacks. a jack for all trades while supporting our troops with 100% usa  Answer:  US
# Phrase:  bring customers high quality products made in the usa. your cart is empty. like this page on facebook! home |  Answer:  US
# Phrase:  us-made materials and suppliers. they are providing good jobs in the us and are now exporting these great products.” john  Answer:  US
# Phrase:  sourced from all over the world. each product is inspected at every step in the production process and before packing  Answer:  NEITHER
# Phrase:  ship directly from our factory to our customers. that means less cost, more convenience, and greater quality control by valco  Answer:  NEITHER
# Phrase:  but world-class quality. we’ve raised our quality standards, and invested in high precision manufacturing equipment, staff training, and state-of-the-art testing  Answer:  NEITHER
# Phrase:  shipments cannot be delivered to po boxes. looking for decoart products outside the united states? we'd love to help find  Answer:  FOREIGN
# Phrase:  top-quality products to independent retailers." locations "reach customers around the world while continuing to bring jobs home." contact us if  Answer:  US
# Phrase:  cheap, overseas substitutes! http://tempflow.com/wp-content/uploads/2017/09/dcf421da-6a23-7636-379d-82d5f2e37234-1.mp3 better business bureau hall of fame for over 16 years our high level of customer care  Answer:  FOREIGN
# Phrase:  the finest materials and components sourced worldwide. learn more proudly americanour products are designed and built in the usa if  Answer:  US
# Phrase:  the usa • hand-forged tools • built to last become a distributor work here privacy terms menu become a distributor  Answer:  US
# Phrase:  in kentucky. to compete successfully against products made in asia, we must focus on producing the highest quality products at  Answer:  FOREIGN
# Phrase:  sustainable product. we have a close relationship with all our suppliers and we oversee each step of our manufacturing process  Answer:  NEITHER
# Phrase:  strategic partner to manufacture your product or outsource a portion of your assembly work, syscom tech’s approach to prioritizing transparency  Answer:  NEITHER
# Phrase:  for men and women are manufactured in our own modern factory in gloversville, new york, usa! we do not import  Answer:  US
# Phrase:  and components sourced worldwide. learn more guaranteed to perform we warrant our products to be free from defects if any  Answer:  NEITHER
# Phrase:  prices. we are committed to this country, its future, and to supporting and promoting manufacturers determined to remain“made in the  Answer:  US
# Phrase:  in the usa quality products. let's commit to buying products made in the usa. i am driving a car made  Answer:  US
# Phrase:  manufacturer in north america, recognized as the most reliable and high-quality provider in the industry. we strive to employ and  Answer:  US
# Phrase:  years serving customers ranging in size from the individual farmer to large multi-national corporations. we manufacture only quality products. all  Answer:  NEITHER
# Phrase:  quality usa made products & service! click here to view our full return/exchange policy > supporting our usa economy couldn't  Answer:  US
# Phrase:  our products are 100% made here in the u.s.a and adhere to strict quality control guidelines.our mission 1836 | n95  Answer:  US
# Phrase:  rigorous international standards of environmentally friendly manufacturing technology. we also stand behind our customers with full product support from development  Answer:  NEITHER
# Phrase:  am provided ... not to mention the expert quality and workmanship of the products they produce. karen - the coca-cola  Answer:  NEITHER
# Phrase:  our products from all over the world. more importantly we are transparent with our sourcing. in fact, we have created  Answer:  NEITHER
# Phrase:  we are committed to serving our customers with the highest quality in warewashing—products that are built to work, and made  Answer:  NEITHER
# Phrase:  outsource any aspect of production, because we won't compromise on quality. tell me more featured blends our weekly favorites we  Answer:  NEITHER
# Phrase:  production cost less than china." "the 'usa made' label allows companies to co-brand with the most powerful brand in the  Answer:  US
# Phrase:  produce "in america, for americans." in an effort to provide front line works with easy access to ppe, the company  Answer:  US
# Phrase:  our products to both large distributors and individual craftsman throughout the world and our focus is on meeting your expectations  Answer:  NEITHER
# Phrase:  screen printed on to high quality goods, in our philadelphia studio. we source the best garments and accessories available, 100%  Answer:  US
# Phrase:  unmatched customer service and manufacturing the best products in the business. all of our products are made in the usa  Answer:  US
# Phrase:  say “produced in america” every vanson is designed, engineered, cut and produced in the u.s.a. of imported and domestic materials,  Answer:  US
# Phrase:  to take the manufacturing off shore- keep the product here, and ship it from here. i can't change the world,  Answer:  FOREIGN
# Phrase:  while processes and technology have changed since our inception, our commitment to quality remains the same. no matter if you  Answer:  NEITHER
# Phrase:  best, and we deliver custom components designed and manufactured for specific applications, servicing markets as diverse as heavy-duty truck, automotive,  Answer:  NEITHER
# Phrase:  quality products have provided our customers with the superior machine parts they demand. to discover more about our operations, make  Answer:  NEITHER
# Phrase:  and value for your money, but world-class quality. we’re consistently raising our quality standards, and investing in high-precision manufacturing equipment,  Answer:  NEITHER
# Phrase:  with local suppliers allows us to deliver a high level of quality and craftsmanship. about us watch dave's orbit story  Answer:  NEITHER
# Phrase:  research and development, we’re able to deliver to our customers the highest quality products they deserve. learn more what is  Answer:  NEITHER
# Phrase:  bit of workmanship.”  5/5 american quality “quality made products that are produced right here in the united states.” still  Answer:  US
# Phrase:  with an emphasis on quality, durability, and longevity. instead of your having to modify imported products to suit your needs,  Answer:  NEITHER
# NEW KEYWORD:  antiforeign_revised_2
# [{'phrase': 'our small workshop in pennsylvania. made in china mass produced in a crowded chinese factory without any love or expertise.', 'certainty': 'High'}, {'phrase': 'quality denim and fabrics from our mill partners in usa, italy and japan a family company based in new york', 'certainty': 'High'}, {'phrase': 'of the 3-4 months typically required when importing from china. small batch customization is a service that is somewhat unique', 'certainty': 'High'}, {'phrase': 'foreign made caskets, in recent years the importing of foreign made caskets & coffins has increased dramatically, the wholesale costs', 'certainty': 'High'}, {'phrase': 'are made in other countries. get infoprivacy policy retailer login follow abilene \ue908 \ue90a newsletter signupemail address: leave this field', 'certainty': 'High'}, {'phrase': 'all clothing and 98 percent of all footwear is imported." -sourcingjournal.com newsletter subscribe to be the first to hear about', 'certainty': 'High'}, {'phrase': 'cheap imports, we take pride in creating quality handmade leather goods using full grain leather. our handmade buffalo leather goods', 'certainty': 'High'}, {'phrase': '“with imported parts” or like notices with our advertising. chippewa apologizes if this caused any confusion to its valued consumers.', 'certainty': 'High'}, {'phrase': 'named "best import product" learn more the choice of oems for manufacturers everywhere. for stopping power anywhere. learn more the', 'certainty': 'High'}, {'phrase': 'every make of used import vehicles for sale, including bmw, honda, hyundai, infiniti, kia, lexus, mazda, mercedes, mini, nissan toyota,', 'certainty': 'High'}, {'phrase': 'cheap imports, we take pride in creating quality handmade leather goods using full grain leather. our handmade buffalo leather goods', 'certainty': 'High'}, {'phrase': 'need it. no foreign factory can match our speed or quality. and our prices are good. that’s our promise. call', 'certainty': 'High'}, {'phrase': 'consumers must take heed and be ever vigilant when it comes to purchasing imported products. corporations continue to rely on', 'certainty': 'High'}, {'phrase': 'capabilities. our products are manufactured in facilities throughout north america and europe. learn more about industry leadership and expertise accuride', 'certainty': 'High'}, {'phrase': 'corporations continue to rely on manufactures overseas because they can produce a lower cost product by using sweatshop labor (even', 'certainty': 'High'}, {'phrase': 'headquartered in china, and we work with a lot of chinese and other countries manufacters, we are in the centre', 'certainty': 'High'}, {'phrase': 'research and development, manufacturing, and assembly operations in belgium, brazil, china, hungary, india, italy, mexico, the united kingdom, and the', 'certainty': 'High'}, {'phrase': "low | best selling | new arrivals comoy's christmas 2017 pebble grain 186 sku: comoyxmas17186 country of originfrance finishsandblast shapebilliard", 'certainty': 'High'}, {'phrase': 'one-of-a-kind item we’ve sourced from artisans across the globe. as a woodworking supply store, we can equip crafters and diyers', 'certainty': 'High'}, {'phrase': 'with that. learn more shipping product from china to the us is a common occurance these days in our global', 'certainty': 'High'}, {'phrase': 'mexico resulting in lower quality products & jobs. we offer legendary service, quality and competitive pricing you can count on,', 'certainty': 'High'}, {'phrase': '39 years. in a time when ruthlessly cheap imports flood the market, we strive to make a product that is', 'certainty': 'High'}, {'phrase': 'which we operate is solely based upon quality and value. material used in our product is imported from various prominent', 'certainty': 'High'}, {'phrase': 'way of life: the command over materials, tools & processes. in an era of ruthlessly cheap imports, we take pride', 'certainty': 'High'}, {'phrase': 'new streamlined manufacturing process best is able ...
